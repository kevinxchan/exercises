# %%
def permute(nums):
    if nums is None:
        return [[]]
    n = len(nums)
    if n <= 1:
        return [nums]
    dp = [[]]
    for num in nums:
        tmp = []
        for p in dp:
            for i in xrange(len(p) + 1):
                tmp.append(p[:i] + [num] + p[i:])
        dp = tmp
    return dp

# %%
print permute(['1', '2', '3'])
# Out:
# <generator object permute at 0x111074c30>
